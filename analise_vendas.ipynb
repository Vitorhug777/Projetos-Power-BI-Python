# %% [markdown]
# Análise de vendas, aprofundamento no mês de Dezembro de 2020

# %%
#importando as bibliotecas
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#obtendo os dados
df = pd.read_csv("/kaggle/input/vendas/tudo.csv")

# %%
#inspecionando as 5 primeiras linhas
df.head(5)
# Out:
#            name                               sale_id  product_id    product  \
# 0  Mason Howell  442bc2f0-22d3-3c8a-9f71-0f9c16cee0b2         296  Lang Club
# 1  Mason Howell  442bc2f0-22d3-3c8a-9f71-0f9c16cee0b2         296  Lang Club
# 2  Mason Howell  442bc2f0-22d3-3c8a-9f71-0f9c16cee0b2         296  Lang Club
# 3  Mason Howell  442bc2f0-22d3-3c8a-9f71-0f9c16cee0b2         296  Lang Club
# 4  Mason Howell  442bc2f0-22d3-3c8a-9f71-0f9c16cee0b2         296  Lang Club
#
#    price_y  quantity   price_x                 created_at  \
# 0  866.694   3.89990  2433.800  1997-09-17 21:50:14+00:00
# 1  866.694   4.00000  1196.580  1997-09-17 21:50:14+00:00
# 2  866.694   1.38452  1975.000  1997-09-17 21:50:14+00:00
# 3  866.694   2.22500   119.526  1997-09-17 21:50:14+00:00
# 4  866.694   2.89000  2386.940  1997-09-17 21:50:14+00:00
#
#                   updated_at                     email
# 0  2007-02-15 19:34:06+00:00  jessica.cole@example.net
# 1  2007-02-15 19:34:06+00:00  jessica.cole@example.net
# 2  2007-02-15 19:34:06+00:00  jessica.cole@example.net
# 3  2007-02-15 19:34:06+00:00  jessica.cole@example.net
# 4  2007-02-15 19:34:06+00:00  jessica.cole@example.net

# %%
df.tail(5)
# Out:
#                     name                               sale_id  product_id  \
# 44495  Ashlynn Jaskolski  3d9d0fd1-0406-3ee8-84ee-5a29be946b2b         235
# 44496  Miss Krista Kuhic  c9b46a89-e252-3e69-9b4c-d2a1f7bd86e8         235
# 44497  Miss Krista Kuhic  c9b46a89-e252-3e69-9b4c-d2a1f7bd86e8         235
# 44498  Miss Krista Kuhic  c9b46a89-e252-3e69-9b4c-d2a1f7bd86e8         235
# 44499  Miss Krista Kuhic  c9b46a89-e252-3e69-9b4c-d2a1f7bd86e8         235
#
#             product  price_y  quantity  price_x                 created_at  \
# 44495  Roselyn Road   3366.3   3.00000  3455.70  2019-12-10 02:43:34+00:00
# 44496  Roselyn Road   3366.3   2.45209  1896.10  1981-03-17 13:05:45+00:00
# 44497  Roselyn Road   3366.3   3.08220  3997.90  1981-03-17 13:05:45+00:00
# 44498  Roselyn Road   3366.3   1.00000  2695.00  1981-03-17 13:05:45+00:00
# 44499  Roselyn Road   3366.3   2.17575  1267.55  1981-03-17 13:05:45+00:00
#
#                       updated_at                         email
# 44495  1981-04-24 06:20:37+00:00   leffler.mafalda@example.net
# 44496  1986-06-24 12:35:27+00:00  leland.vonrueden@example.net
# 44497  1986-06-24 12:35:27+00:00  leland.vonrueden@example.net
# 44498  1986-06-24 12:35:27+00:00  leland.vonrueden@example.net
# 44499  1986-06-24 12:35:27+00:00  leland.vonrueden@example.net

# %%
#verificando a quantidade de linhas e colunas
df.shape
# Out:
# (44500, 10)

# %%
#verificando os nomes de colunas do dataset
df.columns
# Out:
# Index(['name', 'sale_id', 'product_id', 'product', 'price_y', 'quantity',
#        'price_x', 'created_at', 'updated_at', 'email'],
#       dtype='object')

# %%
#resumo estatistico do dataset de vendas, podemos obter alguns insights
df.describe()
# Out:
#          product_id       price_y      quantity       price_x
# count  44500.000000  44500.000000  44500.000000  44500.000000
# mean     300.387640   1897.930295      2.505359   1999.161519
# std       57.734845   1144.833746      1.446676   1155.451744
# min      201.000000     58.000000      0.000000      0.055818
# 25%      250.000000    902.364000      1.241923    994.173000
# 50%      300.000000   1754.000000      2.500000   2001.355000
# 75%      350.000000   2988.600000      3.779000   3001.707500
# max      400.000000   3982.340000      5.000000   4000.000000

# %%
#informações de tipos de dados do dataset
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 44500 entries, 0 to 44499
# Data columns (total 10 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   name        44500 non-null  object
#  1   sale_id     44500 non-null  object
#  2   product_id  44500 non-null  int64
#  3   product     44500 non-null  object
#  4   price_y     44500 non-null  float64
#  5   quantity    44500 non-null  float64
#  6   price_x     44500 non-null  float64
#  7   created_at  44500 non-null  object
#  8   updated_at  44500 non-null  object
#  9   email       44500 non-null  object
# dtypes: float64(3), int64(1), object(6)
# memory usage: 3.4+ MB

# %%
#verificando se há algum valor ausente no data set,e não há.
df.isnull().sum()
# Out:
# name          0
# sale_id       0
# product_id    0
# product       0
# price_y       0
# quantity      0
# price_x       0
# created_at    0
# updated_at    0
# email         0
# dtype: int64

# %%
#filtrando o mês de dezembro de 2019
dezembro_2019 = df.loc[(df['created_at'] >= '2019-12-01') & (df['created_at'] <= '2019-12-31')]

# %%
#mostrar primeiras linhas de dezembro_2020
dezembro_2020.head(10)
# Out:
#                      name                               sale_id  product_id  \
# 4415        Hassan Beatty  6ca52ba9-20b4-32b1-a09e-3078c0f59ba2         269
# 4416        Hassan Beatty  6ca52ba9-20b4-32b1-a09e-3078c0f59ba2         269
# 4417        Hassan Beatty  6ca52ba9-20b4-32b1-a09e-3078c0f59ba2         269
# 4418        Hassan Beatty  6ca52ba9-20b4-32b1-a09e-3078c0f59ba2         269
# 8051      Dr. Parker Dare  b5e2244b-ad51-3429-932c-7093c32ed382         291
# 8053      Dr. Parker Dare  b5e2244b-ad51-3429-932c-7093c32ed382         291
# 8054      Dr. Parker Dare  b5e2244b-ad51-3429-932c-7093c32ed382         291
# 8056      Dr. Parker Dare  b5e2244b-ad51-3429-932c-7093c32ed382         291
# 10962  Marty Medhurst III  940605f3-bb3f-368a-b962-9d08d6d562e5         214
# 10963  Marty Medhurst III  940605f3-bb3f-368a-b962-9d08d6d562e5         214
#
#                   product   price_y  quantity   price_x  \
# 4415         German Place   664.734   1.65432  3994.400
# 4416         German Place   664.734   3.93682  2572.460
# 4417         German Place   664.734   4.12070  2863.000
# 4418         German Place   664.734   4.04000  3664.510
# 8051   Williamson Mission  2638.790   3.43000  2332.720
# 8053   Williamson Mission  2638.790   4.27933   505.465
# 8054   Williamson Mission  2638.790   0.46600  2016.400
# 8056   Williamson Mission  2638.790   2.01054   854.081
# 10962      Melissa Unions  3917.660   1.64568  2258.000
# 10963      Melissa Unions  3917.660   3.00000  2019.390
#
#                       created_at                 updated_at  \
# 4415   2019-12-15 02:53:26+00:00  2000-12-26 02:32:33+00:00
# 4416   2019-12-15 02:53:26+00:00  2000-12-26 02:32:33+00:00
# 4417   2019-12-15 02:53:26+00:00  2000-12-26 02:32:33+00:00
# 4418   2019-12-15 02:53:26+00:00  2000-12-26 02:32:33+00:00
# 8051   2019-12-05 03:15:18+00:00  1983-11-20 13:11:20+00:00
# 8053   2019-12-05 03:15:18+00:00  1983-11-20 13:11:20+00:00
# 8054   2019-12-05 03:15:18+00:00  1983-11-20 13:11:20+00:00
# 8056   2019-12-05 03:15:18+00:00  1983-11-20 13:11:20+00:00
# 10962  2019-12-06 05:13:55+00:00  2013-11-21 17:54:29+00:00
# 10963  2019-12-06 05:13:55+00:00  2013-11-21 17:54:29+00:00
#
#                            email
# 4415   collier.allie@example.com
# 4416   collier.allie@example.com
# 4417   collier.allie@example.com
# 4418   collier.allie@example.com
# 8051          dale74@example.com
# 8053          dale74@example.com
# 8054          dale74@example.com
# 8056          dale74@example.com
# 10962       deonte23@example.com
# 10963       deonte23@example.com

# %%
print(f"A receita total do mês Dezembro de 2020 é {dezembro_2020['price_x'].sum()}")
print(f"A quantidade total de produtos vendidos em Dezembro de 2020 é {dezembro_2020['quantity'].sum()}")
# Out:
# A receita total do mês Dezembro de 2020 é 163900.67
# A quantidade total de produtos vendidos em Dezembro de 2020 é 232.4321106

# %%
#clientes que mais compraram
dezembro_2020['name'].value_counts()
# Out:
# name
# Myrna Reilly            6
# Margaret Beatty         6
# Marta Schimmel Jr.      5
# Tianna Johns V          5
# Philip Walker I         5
# Alta Mayer              5
# Ashlynn Jaskolski       5
# Dr. Zander Okuneva      4
# Prof. Daphnee Kemmer    4
# Laverne Marvin          4
# Dr. Parker Dare         4
# Porter Strosin          4
# Carrie Walsh            4
# Jaime Hackett Jr.       4
# Reid McGlynn            4
# Eulah Torp              4
# Marty Medhurst III      4
# Clark Flatley PhD       4
# Susie Gutkowski         4
# Hassan Beatty           4
# Name: count, dtype: int64

# %%
receita_por_produto = dezembro_2020.groupby('product')['price_x'].sum().reset_index()
receita_por_produto = receita_por_produto.sort_values(by='price_x', ascending=False)

# %%
plt.figure(figsize=(12, 8))
sns.barplot(x='product', y='price_x', data=receita_por_produto, palette='viridis')
plt.title('Total de Receita por Produto - Dezembro 2020')
plt.xlabel('Produto')
plt.ylabel('Total de Receita')
plt.xticks(rotation=40)  # Rotacionar os rótulos do eixo x se necessário
plt.show()

# %%
quantidade_por_produto = dezembro_2020.groupby('product')['quantity'].sum().reset_index()
quantidade_por_produto = quantidade_por_produto.sort_values(by='quantity', ascending=False)

# %%
plt.figure(figsize=(12, 8))

sns.barplot(x='product', y='quantity', data=quantidade_por_produto, palette='viridis')
plt.title('Quantidade de vendas por Produto - Dezembro 2020')
plt.xlabel('Produto')
plt.ylabel('Total de Unidades vendidas')
plt.xticks(rotation=40)  # Rotacionar os rótulos do eixo x se necessário
plt.show()

# %% [markdown]
# Verificamos que o produto mais vendido em Dezembro foi o Darien Mission e o menos vendido o Murphy, este fato não se liga à receita gerada por estes, pois o Mattie Field gerou mais receita e o Murphy Burg não o foi o de menor receita.
# Dito isso, vamos analisar o preço dos produtos.

# %%
dezembro_2020.loc[:, 'receita'] = dezembro_2020['quantity'] * dezembro_2020['price_x']
total_vendas = dezembro_2020.groupby('product').agg({'quantity': 'sum', 'receita': 'sum'}).reset_index()

# %%
mais_vendidos = total_vendas.sort_values(by='quantity', ascending=False)
maior_receita = total_vendas.sort_values(by='receita', ascending=False)

# %%
print("Produtos mais vendidos:")
print(mais_vendidos.head())
# Out:
# Produtos mais vendidos:
#              product   quantity       receita
# 2     Darien Mission  23.273120  33711.843144
# 8       Mattie Field  21.210594  50878.336653
# 6   Mafalda Villages  20.750520  28071.013602
# 12      Roselyn Road  18.280400  41282.072598
# 15        Will Creek  16.922580  36815.462147

# %%
print("\nProdutos com maior receita:")
print(maior_receita.head())
# Out:
# Produtos com maior receita:
#            product   quantity       receita
# 8     Mattie Field  21.210594  50878.336653
# 3     German Place  13.751840  43337.512285
# 12    Roselyn Road  18.280400  41282.072598
# 15      Will Creek  16.922580  36815.462147
# 2   Darien Mission  23.273120  33711.843144

# %%
total_vendas['receita_media_por_unidade'] = total_vendas['receita'] / total_vendas['quantity']
print(total_vendas.sort_values(by='receita_media_por_unidade', ascending=False).head())
# Out:
#            product   quantity       receita  receita_media_por_unidade
# 3     German Place  13.751840  43337.512285                3151.397361
# 9   Melissa Unions   8.915948  23875.495856                2677.841653
# 7      Marquis Run  10.294990  26950.382366                2617.815303
# 8     Mattie Field  21.210594  50878.336653                2398.722858
# 12    Roselyn Road  18.280400  41282.072598                2258.269655

# %%
#vendas diárias
vendas_diarias = dezembro_2020.groupby(dezembro_2020['created_at'].dt.date)['receita'].sum().reset_index()

print("Vendas Diárias em Dezembro:")
print(vendas_diarias)
# Out:
# Vendas Diárias em Dezembro:
#     created_at       receita
# 0   2019-12-03  26950.382366
# 1   2019-12-05  35839.776826
# 2   2019-12-06  11331.702772
# 3   2019-12-08  10730.067077
# 4   2019-12-10  41282.072598
# 5   2019-12-13  20178.657051
# 6   2019-12-15  43337.512285
# 7   2019-12-20  19488.615557
# 8   2019-12-23  10631.747342
# 9   2019-12-24  13533.186092
# 10  2019-12-25  38599.040027
# 11  2019-12-27  22338.566173
# 12  2019-12-28  75682.765944
# 13  2019-12-29  17597.852822
# 14  2019-12-30  30308.762122

# %%
# Calcular vendas diárias
vendas_diarias = dezembro_2020.groupby(dezembro_2020['created_at'].dt.date)['receita'].sum().reset_index()

# Calcular estatísticas: média e quartis
media_vendas = vendas_diarias['receita'].mean()
q1 = vendas_diarias['receita'].quantile(0.25)
q2 = vendas_diarias['receita'].quantile(0.50)
q3 = vendas_diarias['receita'].quantile(0.75)

print("Média das Vendas Diárias:", media_vendas)
print("Quartil 25%:", q1)
print("Quartil 50% (Mediana):", q2)
print("Quartil 75%:", q3)
# Out:
# Média das Vendas Diárias: 27855.380470283762
# Quartil 25%: 15565.519456945
# Quartil 50% (Mediana): 22338.5661725944
# Quartil 75%: 37219.40842635

# %%
# Calcular vendas diárias
vendas_diarias = dezembro_2020.groupby(dezembro_2020['created_at'].dt.date)['receita'].sum().reset_index()

# Configurar o tamanho do gráfico
plt.figure(figsize=(12, 6))

# Plotar as vendas diárias
plt.plot(vendas_diarias['created_at'], vendas_diarias['receita'], marker='o', linestyle='-', label='Vendas Diárias')
plt.axhline(y=media_vendas, color='r', linestyle='--', label='Média')

# Adicionar quartis
plt.axhline(y=q1, color='g', linestyle=':', label='Quartil 25%')
plt.axhline(y=q2, color='b', linestyle=':', label='Quartil 50% (Mediana)')
plt.axhline(y=q3, color='purple', linestyle=':', label='Quartil 75%')

# Adicionar rótulos com os valores das vendas diárias
for index, row in vendas_diarias.iterrows():
    plt.text(row['created_at'], row['receita'], int(row['receita']), ha='center', va='bottom', fontsize=12)

# Adicionar título e rótulos aos eixos
plt.title('Vendas Diárias em Dezembro')
plt.xlabel('Data')
plt.ylabel('Receita')
plt.xticks(vendas_diarias['created_at'], rotation=45)  # Rotacionar os rótulos do eixo x para melhor visualização

# Adicionar grade
plt.grid(True)

# Ajustar layout
plt.tight_layout()

# Mostrar o gráfico
plt.show()
